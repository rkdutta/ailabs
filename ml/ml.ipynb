# %% [markdown]
# ### Canculate mean,median,mode using numpy

# %%
# Example 0
import numpy
from scipy import stats

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.mean(speed)
y = numpy.median(speed)

# The Mode value is the value that appears the most number of times:
# The mode() method returns a ModeResult object that contains the mode number (86), and count (how many times the mode number appeared (3)).
z = stats.mode(speed)

print("mean=",x)
print("median=",y)
print("mode=",z)

# %% [markdown]
# ### Standard Deviation (shortcut σ, pronounce as sigma)
# Standard deviation is a number that describes how spread out the values are.
#
# A low standard deviation means that most of the numbers are close to the mean (average) value.
#
# A high standard deviation means that the values are spread out over a wider range.
#
# Example: This time we have registered the speed of 7 cars:
#
# speed = [86,87,88,86,87,85,86]
#
# The standard deviation is: 0.9
#
# Meaning that most of the values are within the range of 0.9 from the mean value, which is 86.4.

# %%
# Example 1
import numpy

speed = [86,87,88,86,87,85,86]

print("mean = ",numpy.mean(speed))
print("std. dev = ",numpy.std(speed))

# %%
# Example 2
import numpy

speed = [32,111,138,28,59,77,97]

print("mean = ",numpy.mean(speed))
print("std. dev = ",numpy.std(speed))
print("Here the std. dev is very high means the values are scattered from the mean line")

# %% [markdown]
# ### Variance (σ2)
# Variance is another number that indicates how spread out the values are.
#
# In fact, if you take the square root of the variance, you get the standard deviation!
#
# Or the other way around, if you multiply the standard deviation by itself, you get the variance!
#
# To calculate the variance you have to do as follows:

# %%
# Example 3
import numpy

speed = [32,111,138,28,59,77,97]

print("mean = ",numpy.mean(speed))
print("std. dev = ",numpy.std(speed))
print("variance = ",numpy.var(speed))
print("\nImportant: variance = Square root of Std. dev ")
variance = numpy.var(speed)
print("variance = ",variance)
print("sqrt of variance = ",numpy.sqrt(variance),"(this is same as std. dev)")

# %% [markdown]
# ### Create a big data set

# %%
# Create an array containing 250 random floats between 0 and 5:
import numpy
import matplotlib.pyplot as plt

# data set
x = numpy.random.uniform(0.0, 5.0, 250) # 250 random values from 0 - 5
# print(x)

# plot histogram
plt.hist(x,5) # This creates a histogram with 100 bars showing how many values fall into each range.
plt.show() # Whether to wait for all figures to be closed before returning

# %% [markdown]
# #### Histogram Explained
# We use the array from the example above to draw a histogram with 5 bars.
#
# The first bar represents how many values in the array are between 0 and 1.
#
# The second bar represents how many values are between 1 and 2.
#
# Etc.
#
# Which gives us this result:
#
# 52 values are between 0 and 1
# 48 values are between 1 and 2
# 49 values are between 2 and 3
# 51 values are between 3 and 4
# 50 values are between 4 and 5

# %% [markdown]
# ### Normal Data Distribution
#
# An array where the values are concentrated around a given value.
#
# In probability theory this kind of data distribution is known as the normal data distribution, or the Gaussian data distribution.
#
# A normal distribution graph is also known as the bell curve because of it's characteristic shape of a bell.

# %%
import numpy
import matplotlib.pyplot as plt

# Difference between this and revious example is here we have used normal function instead of uniform function
x = numpy.random.normal(5.0, 1.0, 100000) 

plt.hist(x, 100)
plt.show()

# %% [markdown]
# #### Difference between uniform distribution and normal distribution
#
# ```
# Uniform distribution
# np.random.uniform(low, high, size)
# All values in the interval are equally likely.
#
# Probability
#    |
#    |  ───────────────
#    |  |              |
#    |__|______________|____ Value
#       a              b
# ```
#
#
# ```
# normal distribution
# np.random.normal(mean(μ), std(σ), size)
# Values near the mean are more likely.
#
# Probability
#    |
#    |        /\
#    |       /  \
#    |      /    \
#    |_____/______\_____ Value
#             μ
#
# ```

# %%
# uniform Vs normal distribution visual demo
import numpy as np
import matplotlib.pyplot as plt

u = np.random.uniform(0, 50, 50000)
n = np.random.normal(25, 5, 50000)

plt.hist(u, bins=100, alpha=0.5, label="Uniform")
plt.hist(n, bins=100, alpha=0.5, label="Normal")
plt.legend()
plt.show()
